# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
data = pd.read_csv('/content/Tata-steel.csv')
X = data[['Open Price','High Price','Low Price']]
y = data[['Close Price']]
x_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,shuffle = False)

# %%
y_test = y_test.reset_index()[["Close Price"]]
y_test
# Out:
#      Close Price
# 0         273.55
# 1         282.50
# 2         298.45
# 3         273.70
# 4         272.70
# ..           ...
# 292      1184.05
# 293      1172.45
# 294      1166.85
# 295      1163.35
# 296      1135.95
#
# [297 rows x 1 columns]

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.metrics import mean_squared_error



def BuildModel():
 model = Sequential()
 model.add(Dense(30, input_dim=3,activation='relu'))  
 model.add(Dense(1,activation='linear'))
 model.compile(loss="mean_squared_error", optimizer="adam")   
 return model

BuildModel().summary()
regressor = KerasRegressor(build_fn=BuildModel,nb_epoch=400,batch_size=8)
regressor.fit(x_train,y_train) 

y_pred = regressor.predict(X_test)
mse_krr = mean_squared_error(y_test, y_pred)
print(mse_krr)


plt.figure(figsize=(30,10), dpi=80)
plt.rcParams.update({'font.size': 18})
plt.plot(y_test, 'bo-', label="Actual close prices")
plt.plot(y_pred, 'ro-', label="Predicted close prices")
plt.legend(prop={'size': 20})
plt.show()
# Out:
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_86 (Dense)            (None, 30)                120
#
#  dense_87 (Dense)            (None, 1)                 31
#
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# 149/149 [==============================] - 1s 3ms/step - loss: 39936.0234
# 82.25190133166606

# %% [markdown]
# 50% Train Test split

# %%
import pandas as pd
data = pd.read_csv('/content/Tata-steel.csv')
X = data[['Open Price','High Price','Low Price']]
y = data[['Close Price']]
x_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8,shuffle = False)

# %%
y_test = y_test.reset_index()[["Close Price"]]
y_test
# Out:
#       Close Price
# 0          359.05
# 1          361.55
# 2          365.45
# 3          369.30
# 4          376.30
# ...           ...
# 1183      1184.05
# 1184      1172.45
# 1185      1166.85
# 1186      1163.35
# 1187      1135.95
#
# [1188 rows x 1 columns]

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.metrics import mean_squared_error



def BuildModel():
 model = Sequential()
 model.add(Dense(12, input_dim=3,activation='relu'))  
 model.add(Dense(1,activation='linear'))
 model.compile(loss="mean_squared_error", optimizer="adam")   
 return model

BuildModel().summary()
regressor = KerasRegressor(build_fn=BuildModel,nb_epoch=400,batch_size=8)
regressor.fit(x_train,y_train) 

y_pred = regressor.predict(X_test)
mse_krr = mean_squared_error(y_test, y_pred)
print(mse_krr)


plt.figure(figsize=(30,10), dpi=80)
plt.rcParams.update({'font.size': 18})
plt.plot(y_test, 'bo-', label="Actual close prices")
plt.plot(y_pred, 'ro-', label="Predicted close prices")
plt.legend(prop={'size': 20})
plt.show()
# Out:
# Model: "sequential_53"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_106 (Dense)           (None, 12)                48
#
#  dense_107 (Dense)           (None, 1)                 13
#
# ...
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# 38/38 [==============================] - 1s 5ms/step - loss: 268132.6562
# 853668.835962432
